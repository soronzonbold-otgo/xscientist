# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import csv

# %%
x=[]
y=[]
z=[]
with open('q2-result.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=' ')
    for row in plots:
        x.append(row[0])
        y.append(row[1])
        z.append(row[2])

# %%
x=np.array(x).reshape(10000,1)
y=np.array(y).reshape(10000,1)
z=np.array(z).reshape(10000,1)

# %%
#string into the numbers!!!
x=np.double(x)
y=np.double(y)
z=np.double(z)

# %%
print(min(z))
# Out:
# [-0.314941]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(x, y)
# Plot the surface.

ax.scatter(x[:100,:],y[:100,:],z[:100,:],'.')
# Plot the surface.
#surf = ax.plot_surface(X[:100,:], Y[:100,:], z[:100,:], cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)

plt.show()
